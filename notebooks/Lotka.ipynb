# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
x=np.arange(1,101)
y=30/(x**2)

# %%
x=np.arange(1,31)
y=np.sqrt(100./x)

fig=plt.plot(x,y)

# %%
plt.plot(x,np.cumsum(y))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(100/30.)
print(sum(y[0:6]))
print(sum(y[6:30]))
list(enumerate(y))
# Out:
# 3.3333333333333335
# 36.39918936339995
# 59.45211240215226
# [(0, 10.0),
#  (1, 7.0710678118654755),
#  (2, 5.773502691896258),
#  (3, 5.0),
#  (4, 4.47213595499958),
#  (5, 4.08248290463863),
#  (6, 3.779644730092272),
#  (7, 3.5355339059327378),
#  (8, 3.3333333333333335),
#  (9, 3.1622776601683795),
#  (10, 3.0151134457776365),
#  (11, 2.886751345948129),
#  (12, 2.7735009811261455),
#  (13, 2.6726124191242437),
#  (14, 2.581988897471611),
#  (15, 2.5),
#  (16, 2.42535625036333),
#  (17, 2.3570226039551585),
#  (18, 2.2941573387056176),
#  (19, 2.23606797749979),
#  (20, 2.1821789023599236),
#  (21, 2.1320071635561044),
#  (22, 2.0851441405707476),
#  (23, 2.041241452319315),
#  (24, 2.0),
#  (25, 1.9611613513818404),
#  (26, 1.9245008972987525),
#  (27, 1.889822365046136),
#  (28, 1.8569533817705186),
#  (29, 1.8257418583505538)]

# %%
1 = 30 ** x
